# %%
import pandas as pd

# %%
df = pd.read_csv('./summer.csv')

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
pd.__version__
# Out:
# '1.4.1'

# %%
df.City
# Out:
# 0        Athens
# 1        Athens
# 2        Athens
# 3        Athens
# 4        Athens
#           ...
# 31160    London
# 31161    London
# 31162    London
# 31163    London
# 31164    London
# Name: City, Length: 31165, dtype: object

# %%
df.Country.unique()
# Out:
# array(['HUN', 'AUT', 'GRE', 'USA', 'GER', 'GBR', 'FRA', 'AUS', 'DEN',
#        'SUI', 'ZZX', 'NED', 'BEL', 'IND', 'CAN', 'BOH', 'SWE', 'NOR',
#        'ESP', 'ITA', 'CUB', 'ANZ', 'RSA', 'FIN', 'RU1', 'EST', 'TCH',
#        'NZL', 'BRA', 'JPN', 'LUX', 'ARG', 'POL', 'POR', 'URU', 'YUG',
#        'ROU', 'HAI', 'EGY', 'PHI', 'IRL', 'CHI', 'LAT', 'MEX', 'TUR',
#        'PAN', 'JAM', 'SRI', 'KOR', 'PUR', 'PER', 'IRI', 'TRI', 'URS',
#        'VEN', 'BUL', 'LIB', 'EUA', 'ISL', 'PAK', 'BAH', 'BWI', 'TPE',
#        'ETH', 'MAR', 'GHA', 'IRQ', 'SIN', 'TUN', 'KEN', 'NGR', 'GDR',
#        'FRG', 'UGA', 'CMR', 'MGL', 'PRK', 'COL', 'NIG', 'THA', 'BER',
#        'TAN', 'GUY', 'ZIM', 'CHN', 'CIV', 'ZAM', 'DOM', 'ALG', 'SYR',
#        'SUR', 'CRC', 'INA', 'SEN', 'DJI', 'AHO', 'ISV', 'EUN', 'NAM',
#        'QAT', 'LTU', 'MAS', 'CRO', 'ISR', 'SLO', 'IOP', 'RUS', 'UKR',
#        'ECU', 'BDI', 'MOZ', 'CZE', 'BLR', 'TGA', 'KAZ', 'UZB', 'SVK',
# ...

# %%
df.shape
# Out:
# (31165, 9)

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
jo = df[df.Athlete == 'OWENS, Jesse']
jo
# Out:
#       Year    City      Sport Discipline       Athlete Country Gender  \
# 6427  1936  Berlin  Athletics  Athletics  OWENS, Jesse     USA    Men
# 6439  1936  Berlin  Athletics  Athletics  OWENS, Jesse     USA    Men
# 6456  1936  Berlin  Athletics  Athletics  OWENS, Jesse     USA    Men
# 6523  1936  Berlin  Athletics  Athletics  OWENS, Jesse     USA    Men
#
#              Event Medal
# 6427          100M  Gold
# 6439          200M  Gold
# 6456  4X100M Relay  Gold
# 6523     Long Jump  Gold

# %%
jo.Event.value_counts()
# Out:
# 100M            1
# 200M            1
# 4X100M Relay    1
# Long Jump       1
# Name: Event, dtype: int64

# %%
df1 = df[df.Sport == 'Badminton'].Country.value_counts()
df1
# Out:
# CHN    59
# KOR    33
# INA    26
# DEN     9
# MAS     7
# GBR     4
# JPN     2
# RUS     2
# NED     1
# IND     1
# Name: Country, dtype: int64

# %%
rec = df[df.Year >= 1984]
rec['Country'].value_counts().reset_index()
# Out:
#     index  Country
# 0     USA     2087
# 1     AUS      876
# 2     CHN      807
# 3     GER      785
# 4     RUS      768
# ..    ...      ...
# 128   BDI        1
# 129   URU        1
# 130   SRI        1
# 131   BAR        1
# 132   GAB        1
#
# [133 rows x 2 columns]

# %%
df[(df.Gender == 'Men') & (df.Medal == 'Gold') & (df.Event == '100M Freestyle')].sort_values('Athlete')
# Out:
#        Year                   City     Sport Discipline  \
# 29276  2012                 London  Aquatics   Swimming
# 27231  2008                Beijing  Aquatics   Swimming
# 18082  1988                  Seoul  Aquatics   Swimming
# 6348   1936                 Berlin  Aquatics   Swimming
# 1144   1908                 London  Aquatics   Swimming
# 9814   1960                   Rome  Aquatics   Swimming
# 16623  1984            Los Angeles  Aquatics   Swimming
# 0      1896                 Athens  Aquatics   Swimming
# 674    1904               St Louis  Aquatics   Swimming
# 8929   1956  Melbourne / Stockholm  Aquatics   Swimming
# 2841   1920                Antwerp  Aquatics   Swimming
# 1953   1912              Stockholm  Aquatics   Swimming
# 5733   1932            Los Angeles  Aquatics   Swimming
# 13931  1976               Montreal  Aquatics   Swimming
# 21333  1996                Atlanta  Aquatics   Swimming
# 19628  1992              Barcelona  Aquatics   Swimming
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from matplotlib.colors import ListedColormap

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
chn = df[(df.Year==2008) & (df.Country=='CHN')]
chn
# Out:
#        Year     City          Sport       Discipline           Athlete  \
# 27176  2008  Beijing       Aquatics           Diving       ZHOU, Luxin
# 27177  2008  Beijing       Aquatics           Diving         WANG, Xin
# 27178  2008  Beijing       Aquatics           Diving      CHEN, Ruolin
# 27180  2008  Beijing       Aquatics           Diving          QIN, Kai
# 27181  2008  Beijing       Aquatics           Diving         HE, Chong
# ...     ...      ...            ...              ...               ...
# 29138  2008  Beijing  Weightlifting    Weightlifting        LI, Hongli
# 29140  2008  Beijing  Weightlifting    Weightlifting          LU, Yong
# 29156  2008  Beijing      Wrestling  Wrestling Free.            XU, Li
# 29171  2008  Beijing      Wrestling  Wrestling Free.        WANG, Jiao
# 29204  2008  Beijing      Wrestling  Wrestling Gre-R  CHANG, Yongxiang
#
#       Country Gender           Event   Medal
# 27176     CHN    Men    10M Platform  Silver
# ...

# %%
sns.set()
sns.countplot(x='Medal',hue='Gender',data=chn, palette='RdBu', order=['Gold','Silver','Bronze']);

# %%
chn.Medal.value_counts().plot(kind='bar', color=['gold','brown','silver'])
chn.Gender.value_counts().plot(kind='bar', color=['red','blue'])
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Medal',hue='Gender', data=df, order=['Gold','Silver','Bronze'])
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
ath = df.set_index('Athlete')
ath
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
ath.sort_index()
# Out:
#                           Year      City       Sport   Discipline Country  \
# Athlete
# AABYE, Edgar              1900     Paris  Tug of War   Tug of War     ZZX
# AALTONEN, Arvo Ossian     1920   Antwerp    Aquatics     Swimming     FIN
# AALTONEN, Arvo Ossian     1920   Antwerp    Aquatics     Swimming     FIN
# AALTONEN, Paavo Johannes  1948    London  Gymnastics  Artistic G.     FIN
# AALTONEN, Paavo Johannes  1952  Helsinki  Gymnastics  Artistic G.     FIN
# ...                        ...       ...         ...          ...     ...
# ÖSTMO, Ole                1900     Paris    Shooting     Shooting     NOR
# ÖSTMO, Ole                1900     Paris    Shooting     Shooting     NOR
# ÖSTMO, Ole                1900     Paris    Shooting     Shooting     NOR
# ÖSTMO, Ole                1900     Paris    Shooting     Shooting     NOR
# ÖSTRAND, Per-Olof         1952  Helsinki    Aquatics     Swimming     SWE
#
#                          Gender                          Event   Medal
# ...

# %%
df.loc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Athlete        HAJOS, Alfred
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: 0, dtype: object

# %%
medals_by_year = df.groupby('Year').Medal.value_counts()
total_medals = medals_by_year.unstack()
total_medals['Total Medals']= total_medals['Bronze']+ total_medals['Gold']+ total_medals['Silver']
print(total_medals)
total_medals.plot(kind='bar',figsize=(15,8), stacked=True)
# Out:
# Medal  Bronze  Gold  Silver  Total Medals
# Year
# 1896       40    64      47           151
# 1900      142   178     192           512
# 1904      123   188     159           470
# 1908      211   311     282           804
# 1912      284   301     300           885
# 1920      355   497     446          1298
# 1924      285   301     298           884
# 1928      242   229     239           710
# 1932      196   213     206           615
# 1936      282   299     294           875
# 1948      268   276     270           814
# 1952      299   300     290           889
# 1956      297   298     290           885
# 1960      301   295     286           882
# 1964      343   330     337          1010
# 1968      351   341     339          1031
# 1972      412   387     386          1185
# 1976      447   429     429          1305
# 1980      472   460     455          1387
# 1984      500   483     476          1459
# 1988      535   506     505          1546
# ...

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
df.Year.value_counts().sort_index()
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# 2012    1949
# Name: Year, dtype: int64

# %%
print(df.groupby('Year').size())
print(df.groupby('Year').size().index)
print(df.groupby('Year').size().values)
# Out:
# Year
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# 2012    1949
# dtype: int64
# Int64Index([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#             1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#             1996, 2000, 2004, 2008, 2012],
#            dtype='int64', name='Year')
# [ 151  512  470  804  885 1298  884  710  615  875  814  889  885  882
#  1010 1031 1185 1305 1387 1459 1546 1705 1859 2015 1998 2042 1949]

# %%
df[df.Athlete == 'LEWIS, Carl'].groupby('Athlete').size()
# Out:
# Athlete
# LEWIS, Carl    10
# dtype: int64

# %%
df.groupby('Year').Medal.value_counts().unstack().plot(kind='line', figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df.groupby('Country').agg({'Year':['count','min','max']})
# Out:
#          Year
#         count   min   max
# Country
# AFG         2  2008  2012
# AHO         1  1988  1988
# ALG        15  1984  2012
# ANZ        29  1908  1912
# ARG       259  1924  2012
# ...       ...   ...   ...
# VIE         2  2000  2008
# YUG       435  1924  2000
# ZAM         2  1984  1996
# ZIM        23  1980  2008
# ZZX        48  1896  1904
#
# [147 rows x 3 columns]

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df[(df.City=='Beijing') & ((df.Event=='100M Freestyle') | (df.Event=='200M Freestyle'))].groupby(['Event','Athlete','Medal']).size().unstack().fillna(0)
# Out:
# Medal                                Bronze  Gold  Silver
# Event          Athlete
# 100M Freestyle BERNARD, Alain           0.0   1.0     0.0
#                CIELO FILHO, Cesar       1.0   0.0     0.0
#                COUGHLIN, Natalie        1.0   0.0     0.0
#                LEZAK, Jason             1.0   0.0     0.0
#                STEFFEN, Britta          0.0   1.0     0.0
#                SULLIVAN, Eamon          0.0   0.0     1.0
#                TRICKETT, Lisbeth        0.0   0.0     1.0
# 200M Freestyle ISAKOVIC, Sara           0.0   0.0     1.0
#                PANG, Jiaying            1.0   0.0     0.0
#                PARK, Taehwan            0.0   0.0     1.0
#                PELLEGRINI, Federica     0.0   1.0     0.0
#                PHELPS, Michael          0.0   1.0     0.0
#                VANDERKAAY, Peter        1.0   0.0     0.0

# %%
df[(df.Country == 'USA') & (df.Medal == 'Gold')]
# Out:
#        Year    City       Sport           Discipline  \
# 13     1896  Athens   Athletics            Athletics
# 15     1896  Athens   Athletics            Athletics
# 21     1896  Athens   Athletics            Athletics
# 27     1896  Athens   Athletics            Athletics
# 29     1896  Athens   Athletics            Athletics
# ...     ...     ...         ...                  ...
# 30955  2012  London      Tennis               Tennis
# 30970  2012  London  Volleyball     Beach Volleyball
# 30971  2012  London  Volleyball     Beach Volleyball
# 31125  2012  London   Wrestling  Wrestling Freestyle
# 31133  2012  London   Wrestling  Wrestling Freestyle
#
#                         Athlete Country Gender             Event Medal
# 13                BURKE, Thomas     USA    Men              100M  Gold
# 15               CURTIS, Thomas     USA    Men      110M Hurdles  Gold
# 21                BURKE, Thomas     USA    Men              400M  Gold
# ...

# %%
us_mw_gold = df[(df.Country == 'USA') & (df.Medal == 'Gold')].groupby(['Year','Gender']).size().unstack().fillna(0)
us_mw_gold.sort_values(by='Year',ascending=False).plot(kind='barh', figsize=(15,10))
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
chn_mw_gold = df[(df.Country == 'CHN') & (df.Medal == 'Gold')].groupby(['Year','Gender']).size().unstack().fillna(0)
chn_mw_gold
# chn_mw_gold.sort_values(by='Year',ascending=False).plot(kind='barh', figsize=(15,10), color=['green','pink'])
# Out:
# Gender  Men  Women
# Year
# 1984     10     16
# 1988      3      3
# 1992      5     13
# 1996      8     11
# 2000     19     20
# 2004     16     36
# 2008     34     40
# 2012     27     29

# %%
df.groupby(['Athlete','Medal']).size().unstack().fillna(0).sort_values('Gold',ascending=False).Gold.head().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Athlete'>

# %%
df.groupby(['Athlete','Medal']).size().unstack().fillna(0).sort_values('Silver',ascending=False).Silver.head().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Athlete'>

# %%
df.groupby(['Athlete','Medal']).size().unstack().fillna(0).sort_values('Bronze',ascending=False).Bronze.head().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Athlete'>

# %%
df.groupby(['Athlete','Medal']).size().unstack().fillna(0).sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head().plot(kind='bar', figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
ita_fra_ger = df[(df.Country == 'ITA') | (df.Country == 'FRA') | (df.Country == 'GER')]
ita_fra_ger.groupby(['Country','Medal']).size().unstack()[['Gold','Silver','Bronze']].plot(kind='barh',figsize=(10,8), color=['gold','silver','brown'])
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
olympic_2008 = df[df.Year == 2008]
olympic_2008
# Out:
#        Year     City      Sport       Discipline               Athlete  \
# 27174  2008  Beijing   Aquatics           Diving        GALPERIN, Gleb
# 27175  2008  Beijing   Aquatics           Diving      MITCHAM, Matthew
# 27176  2008  Beijing   Aquatics           Diving           ZHOU, Luxin
# 27177  2008  Beijing   Aquatics           Diving             WANG, Xin
# 27178  2008  Beijing   Aquatics           Diving          CHEN, Ruolin
# ...     ...      ...        ...              ...                   ...
# 29211  2008  Beijing  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  2008  Beijing  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  2008  Beijing  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  2008  Beijing  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  2008  Beijing  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#       Country Gender         Event   Medal
# 27174     RUS    Men  10M Platform  Bronze
# ...

# %%
h_map = olympic_2008.groupby(['Country','Medal']).size().unstack(fill_value=0)[['Gold','Silver','Bronze']].sort_values(['Gold','Silver','Bronze'],ascending=False)
h_map
# Out:
# Medal    Gold  Silver  Bronze
# Country
# USA       125     109      81
# CHN        74      53      57
# RUS        43      44      56
# GER        42      16      43
# KOR        41      11      26
# ...       ...     ...     ...
# ISR         0       0       1
# MDA         0       0       1
# MRI         0       0       1
# TOG         0       0       1
# VEN         0       0       1
#
# [86 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(h_map)
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='Country'>

# %%
sns.palplot(sns.color_palette())

# %%
usa = df[df.Country == 'USA']
usa
# Out:
#        Year    City       Sport           Discipline  \
# 11     1896  Athens   Athletics            Athletics
# 13     1896  Athens   Athletics            Athletics
# 15     1896  Athens   Athletics            Athletics
# 19     1896  Athens   Athletics            Athletics
# 21     1896  Athens   Athletics            Athletics
# ...     ...     ...         ...                  ...
# 31035  2012  London  Volleyball           Volleyball
# 31099  2012  London   Wrestling  Wrestling Freestyle
# 31112  2012  London   Wrestling  Wrestling Freestyle
# 31125  2012  London   Wrestling  Wrestling Freestyle
# 31133  2012  London   Wrestling  Wrestling Freestyle
#
#                              Athlete Country Gender         Event   Medal
# 11                     LANE, Francis     USA    Men          100M  Bronze
# 13                     BURKE, Thomas     USA    Men          100M    Gold
# 15                    CURTIS, Thomas     USA    Men  110M Hurdles    Gold
# ...

# %%
usa_winners = usa.groupby(['Year','Athlete','Medal']).size().unstack(fill_value=0)
usa_winners['Total']=usa_winners['Gold']+ usa_winners['Silver']+usa_winners['Bronze']
usa_winners
# Out:
# Medal                  Bronze  Gold  Silver  Total
# Year Athlete
# 1896 BLAKE, Arthur          0     0       1      1
#      BURKE, Thomas          0     2       0      2
#      CLARK, Ellery          0     2       0      2
#      CONNOLLY, James        1     1       1      3
#      CURTIS, Thomas         0     1       0      1
# ...                       ...   ...     ...    ...
# 2012 WILLIAMS, Lauryn       0     1       0      1
#      WILLIAMS, Serena       0     2       0      2
#      WILLIAMS, Venus        0     1       0      1
#      WINDES, Elsie          0     1       0      1
#      WUKIE, Jacob           0     0       1      1
#
# [3752 rows x 4 columns]

# %%
usa_winners = usa_winners.reset_index()[['Year','Athlete','Total']]
year = []
athlete = []
medal = []
for y in usa_winners.Year.unique():
    new_df = usa_winners[usa_winners.Year == y]
    y_ath_m = new_df.sort_values('Total',ascending=False).iloc[0]
    year.append(y_ath_m[0])
    athlete.append(y_ath_m[1])
    medal.append(y_ath_m[2])
usa_top_winners = pd.DataFrame({'Year':year, 'Athlete':athlete, 'Total':medal})
usa_top_winners
# Out:
#     Year                      Athlete  Total
# 0   1896              GARRETT, Robert      4
# 1   1900               BAXTER, Irving      5
# 2   1904                 HEIDA, Anton      6
# 3   1908             SHERIDAN, Martin      3
# 4   1912        OSBURN, Carl Townsend      4
# 5   1920                  LEE, Willis      7
# 6   1924          WEISSMULLER, Johnny      4
# 7   1928       OSIPOWICH, Albina Lucy      2
# 8   1932           DIDRIKSON, Mildred      3
# 9   1936                 OWENS, Jesse      4
# 10  1948      MCLANE, James Price Jr.      3
# 11  1952          KONNO, Ford Hiroshi      3
# 12  1956        MORROW, Robert Joseph      3
# 13  1960  VON SALTZA, Susan Christina      4
# 14  1964        STOUDER, Sharon Marie      4
# 15  1968    HICKCOX, Charles Buchanan      4
# 16  1972                  SPITZ, Mark      7
# 17  1976    BABASHOFF, Shirley Farber      5
# 18  1984             RETTON, Mary-Lou      5
# 19  1988              BIONDI, Matthew      7
# ...

# %%
usa_top_winners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     26 non-null     int64
#  1   Athlete  26 non-null     object
#  2   Total    26 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 752.0+ bytes

# %%
usa_top_winners['Year']=usa_top_winners['Year'].astype(str)
usa_top_winners['Brief']=usa_top_winners['Athlete']+ ' / ' +usa_top_winners['Year']
usa_top_winners
# Out:
#     Year                      Athlete  Total  \
# 0   1896              GARRETT, Robert      4
# 1   1900               BAXTER, Irving      5
# 2   1904                 HEIDA, Anton      6
# 3   1908             SHERIDAN, Martin      3
# 4   1912        OSBURN, Carl Townsend      4
# 5   1920                  LEE, Willis      7
# 6   1924          WEISSMULLER, Johnny      4
# 7   1928       OSIPOWICH, Albina Lucy      2
# 8   1932           DIDRIKSON, Mildred      3
# 9   1936                 OWENS, Jesse      4
# 10  1948      MCLANE, James Price Jr.      3
# 11  1952          KONNO, Ford Hiroshi      3
# 12  1956        MORROW, Robert Joseph      3
# 13  1960  VON SALTZA, Susan Christina      4
# 14  1964        STOUDER, Sharon Marie      4
# 15  1968    HICKCOX, Charles Buchanan      4
# 16  1972                  SPITZ, Mark      7
# 17  1976    BABASHOFF, Shirley Farber      5
# 18  1984             RETTON, Mary-Lou      5
# 19  1988              BIONDI, Matthew      7
# ...

# %%
usa_top_winners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     26 non-null     object
#  1   Athlete  26 non-null     object
#  2   Total    26 non-null     int64
#  3   Brief    26 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 960.0+ bytes

# %%
usa_top_winners.plot(kind='barh',x='Brief',figsize=(15,10))
# Out:
# <AxesSubplot:ylabel='Brief'>
